# %% [markdown]
# # Normal (Gaussian) Distribution

# %% [raw]
# التوزيع الطبيعي هو أحد أهم التوزيعات.
# ويسمى أيضًا التوزيع الغاوسي نسبة لعالم الرياضيات الألماني كارل فريدريش جاوس.
# يناسب التوزيع الاحتمالي للعديد من الأحداث ، على سبيل المثال. درجات معدل الذكاء ونبض القلب وما إلى ذلك.
# استخدم طريقة random.normal () للحصول على توزيع بيانات عادي.

# %% [raw]
# It has three parameters:
#
#     loc - (Mean) حيث توجد ذروة الجرس.
#
#     scale - (Standard Deviation) إلى أي مدى يجب أن يكون توزيع الرسم البياني مسطحًا.
#
#     size - شكل المصفوفة التي تم إرجاعها

# %%
#قم بإنشاء توزيع عادي عشوائي بحجم 2*3
from numpy import random

x = random.normal(size=(2, 3))

print(x)
# Out:
# [[-0.0379114  -0.72915992 -0.83857844]
#  [ 0.75597648  0.48368066 -0.70571964]]

# %%
#قم بإنشاء توزيع عادي عشوائي للحجم 2*3 بمتوسط 1 وانحراف معياري 2
from numpy import random

x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[-0.24574797  2.25805078 -3.08466583]
#  [-2.19032704  1.59905868  1.77974489]]

# %% [markdown]
# ## Visualization of Normal Distribution   ---  تصور التوزيع الطبيعى

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000), hist=False)

plt.show()

# %% [markdown]
# ملاحظة: يُعرف منحنى التوزيع الطبيعي أيضًا باسم منحنى الجرس بسبب منحنى على شكل جرس.
