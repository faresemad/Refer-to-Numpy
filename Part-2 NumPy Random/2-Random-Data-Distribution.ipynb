# %% [markdown]
# # Scorpion

# %% [markdown]
# ## What is Data Distribution?

# %% [raw]
# #توزيع البيانات عبارة عن قائمة بجميع القيم الممكنة وعدد مرات حدوث كل قيمة.
# #هذه القوائم مهمة عند العمل مع الإحصاء وعلوم البيانات.
# #تقدم الوحدة النمطية العشوائية طرقًا تُرجع توزيعات البيانات التي تم إنشاؤها عشوائيًا.

# %% [markdown]
# ## Random Distribution

# %% [raw]
# #التوزيع العشوائي هو مجموعة من الأرقام العشوائية التي تتبع دالة كثافة احتمالية معينة.

# %% [raw]
# سوف ننشئ مصفوفه احاديه الابعاد يحتوى علي 100 قيمه حيث كل قيمه تكون 3 او 5 او 7 او 9
# تم تعيين احتمال أن تكون القيمة 3 على 0.1.
# تم تعيين احتمال القيمة لتكون 5 على 0.3.
# تم تعيين احتمال أن تكون القيمة 7 على 0.6.
# تم تعيين احتمالية أن تكون القيمة 9 على 0
# يجب ان تكون مجموع اااحتماليه تساوى 1

# %%
from numpy import random
# p هى التى سنضع فيها قيم الاحتماليه
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))
print(x)
# Out:
# [5 5 7 7 5 7 3 7 5 5 7 3 7 5 3 7 7 7 7 7 7 7 7 7 7 7 5 5 7 7 7 7 7 7 7 7 7
#  5 3 7 7 7 3 3 7 3 7 7 5 7 7 7 7 3 5 7 5 7 7 7 7 5 7 7 5 3 7 7 7 7 7 7 7 7
#  7 7 7 3 7 3 5 7 7 5 7 5 3 7 7 7 5 7 5 7 7 7 5 7 7 7]

# %% [raw]
# #يمكنك إرجاع مصفوفات من أي شكل وحجم عن طريق تحديد الشكل في معلمة الحجم.

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))
print(x)
# Out:
# [[7 5 5 5 7]
#  [7 7 5 7 5]
#  [7 7 5 5 7]]
